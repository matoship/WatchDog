# %%
import pickle

# %%
data = pickle.loads(open("faceEncodings.pickle", "rb").read())
print("Data:", data)
# Out:
# Data: {'encodings': [array([-5.53606749e-02,  1.28151461e-01,  7.95382559e-02, -3.66102043e-03,
#        -6.95961565e-02, -4.79480624e-02, -9.27965492e-02, -2.97033414e-03,
#         1.22564144e-01, -2.82914322e-02,  2.44923100e-01,  6.78425562e-03,
#        -2.39408433e-01,  3.15645454e-03, -9.90017131e-03,  9.11299586e-02,
#        -1.50307551e-01, -4.14570160e-02, -1.29856735e-01, -1.13407783e-01,
#         3.56478579e-02,  7.19107548e-03,  1.91819910e-02, -1.22657424e-04,
#        -1.04496337e-01, -2.73905307e-01, -7.71390870e-02, -1.09948069e-01,
#         9.92191136e-02, -2.02997625e-01,  4.51915758e-03,  2.08270848e-02,
#        -1.09445117e-01, -2.84352098e-02, -1.46404430e-02,  8.14525038e-03,
#         2.06618756e-02, -8.11063945e-02,  1.68766022e-01, -1.71792172e-02,
#        -1.63600355e-01, -3.96901369e-02, -1.39488478e-03,  2.51006424e-01,
#         1.95394680e-01,  6.09239191e-02,  1.35771995e-02, -5.82708567e-02,
# ...

# %%
for name in (['Kaifeng', 'Anupama', 'Revanth']):
    # print encoding of each person
    print("Encoding of", name, ":", data[name])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 for name in (['Kaifeng', 'Anupama', 'Revanth']):
#       2     # print encoding of each person
# ----> 3     print("Encoding of", name, ":", data[name])
#
# KeyError: 'Kaifeng'
